# %%
import pandas as pd
import numpy as np
import os
import sys
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from IPython.display import Audio
import keras
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from keras.utils import to_categorical
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import zipfile
import os

# %%
PATH= r"C:\Users\USER\Downloads\AudioWAV"

# %%
# Get the list of files in the directory
directory_list = os.listdir(PATH)

# Initialize lists to store file paths and emotions
file_emotion = []
file_path = []

# Process each file in the directory
for file in directory_list:
    if file.endswith(".wav"):  # Process only WAV files
        file_path.append(os.path.join(PATH, file))  # Correct path concatenation
        part = file.split('_')

        # Extract emotion from filename
        emotion_code = part[2]  # Adjust if the emotion is stored in a different index
        emotion_dict = {
            'SAD': 'sad',
            'ANG': 'angry',
            'DIS': 'disgust',
            'FEA': 'fear',
            'HAP': 'happy',
            'NEU': 'neutral'
        }
        file_emotion.append(emotion_dict.get(emotion_code, 'Unknown'))  # Default to 'Unknown'

# Create DataFrame
crema_df = pd.DataFrame({'Emotions': file_emotion, 'Path': file_path})

# Save to CSV for future use
crema_df.to_csv("crema_df.csv", index=False)

# Display first few rows
print("✅ DataFrame Created Successfully!")
print(crema_df.head())
# Out:
# ✅ DataFrame Created Successfully!
#   Emotions                                               Path
# 0    angry  C:\Users\USER\Downloads\AudioWAV\1001_DFA_ANG_...
# 1  disgust  C:\Users\USER\Downloads\AudioWAV\1001_DFA_DIS_...
# 2     fear  C:\Users\USER\Downloads\AudioWAV\1001_DFA_FEA_...
# 3    happy  C:\Users\USER\Downloads\AudioWAV\1001_DFA_HAP_...
# 4  neutral  C:\Users\USER\Downloads\AudioWAV\1001_DFA_NEU_...

# %%
plt.title('Count of Emotions')
sns.countplot(x = crema_df.Emotions)
plt.ylabel('Count')
plt.xlabel('Emotions')
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %%
def waveplot(data, sr, e):
  plt.figure(figsize = (10, 3))
  plt.title(f"{e} audio waveplot")
  librosa.display.waveshow(data, sr = sr)

def spectrogram(data, sr, e):
  X = librosa.stft(data)
  Xdb = librosa.amplitude_to_db(abs(X))
  plt.figure(figsize = (12, 3))
  plt.title(f"{e} audio spectrogram")
  librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=crema_df.Emotions, order=crema_df.Emotions.value_counts().index, palette="Set2")
plt.title('Count of Emotions')
plt.ylabel('Count')
plt.xlabel('Emotions')
sns.despine()
plt.show()

# Define function to plot waveplot
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 3))
    plt.title(f"{emotion} Audio Waveplot")
    librosa.display.waveshow(data, sr=sr)
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.show()

# Define function to plot spectrogram
def spectrogram(data, sr, emotion):
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(12, 3))
    plt.title(f"{emotion} Audio Spectrogram")
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(label="dB")
    plt.show()
emotion = 'happy'
path = np.array(crema_df.Path[crema_df.Emotions == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)

# %%
emotion = 'happy'
path = np.array(crema_df.Path[crema_df.Emotions == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(crema_df.Path[crema_df.Emotions == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def noise(data):
  noise_amp = 0.035 * np.random.uniform() * np.amax(data)
  data = data + noise_amp * np.random.normal(size = data.shape[0])
  return data

def stretch(data, rate = 0.8):
  return librosa.effects.time_stretch(data, rate = rate)

def shift(data):
  shift_range = int(np.random.uniform(low = -5, high = 5) * 1000)
  return np.roll(data, shift_range)

def pitch(data, sampling_rate, n_steps = 0.7):
  return librosa.effects.pitch_shift(data, sr = sampling_rate, n_steps = n_steps)

path = np.array(crema_df.Path)[1]
data, sample_rate = librosa.load(path)

# %%
# Simple audio
plt.figure(figsize = (14, 4))
librosa.display.waveshow(y = data, sr = sample_rate)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Noise
x = noise(data)
plt.figure(figsize = (14, 4))
librosa.display.waveshow(y = x, sr = sample_rate)
Audio(x, rate = sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Stretch
x = stretch(data)
plt.figure(figsize = (14, 4))
librosa.display.waveshow(y = x, sr = sample_rate)
Audio(x, rate = sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
 #Shift
x = shift(data)
plt.figure(figsize = (14, 4))
librosa.display.waveshow(y = x, sr = sample_rate)
Audio(x, rate = sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Pitch
x = pitch(data, sampling_rate = sample_rate)
plt.figure(figsize = (14, 4))
librosa.display.waveshow(y = x, sr = sample_rate)
Audio(x, rate = sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_features(data):
    result = np.array([])

    mfcc = np.mean(librosa.feature.mfcc(y = data, sr = sample_rate, n_mfcc = 20).T, axis = 0)
    result = np.hstack((result, mfcc))

    return result

def get_features(path):
    data, sample_rate = librosa.load(path, duration = 2.5, offset = 0.6)

    res1 = extract_features(data)
    result = np.array(res1)

    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2))

    lowspeed_data = stretch(data, rate = 0.7)
    res3 = extract_features(lowspeed_data)
    result = np.vstack((result, res3))

    highspeed_data = stretch(data, rate = 1.25)
    res4 = extract_features(highspeed_data)
    result = np.vstack((result, res4))

    pitch_data = pitch(data, sample_rate, n_steps = 0.8)
    res5 = extract_features(pitch_data)
    result = np.vstack((result, res5))

    shift_data = shift(data)
    res6 = extract_features(shift_data)
    result = np.vstack((result, res6))

    return result

# %%
X, Y = [], []
for path, emotion in zip(crema_df.Path, crema_df.Emotions):
    feature = get_features(path)
    for ele in feature:
        X.append(ele)
        Y.append(emotion)

# %%
from concurrent.futures import ThreadPoolExecutor

def process_audio_file(path, emotion, X, Y):
    feature = get_features(path)
    for ele in feature:
        X.append(ele)
        Y.append(emotion)
    return (path, emotion)

if __name__ == "__main__":
    X, Y = [], []
    with ThreadPoolExecutor() as executor:
        futures = []
        for path, emotion in zip(crema_df.Path, crema_df.Emotions):
            future = executor.submit(process_audio_file, path, emotion, X, Y)
            futures.append(future)

        for future in futures:
            path, emotion = future.result()
#             print(path, " : ", emotion)

# %%
len(X), len(Y), crema_df.Path.shape
# Out:
# (44652, 44652, (7442,))

# %%
features = pd.DataFrame(X)
features['labels'] = Y
features.to_csv('features.csv', index = False)
features.head()
# Out:
#             0           1          2          3          4          5  \
# 0 -343.071167  123.145836 -18.152159  45.152039   3.317023  11.820990
# 1 -300.047403   81.804242   0.503422  32.365562  12.522935   2.114115
# 2 -377.348511  117.542236 -16.562212  42.161098   5.616234   9.837592
# 3 -370.535492  122.146843 -20.278606  43.588318   3.125001  11.503021
# 4 -369.991577  120.898537 -18.934263  46.482712   1.650506   9.119425
#
#            6         7          8         9  ...        11        12  \
# 0 -28.171919  3.126865  -8.081865 -5.423733  ... -3.102307 -1.432722
# 1 -18.332299 -3.137690  -5.573087 -6.692385  ... -3.299655 -3.436120
# 2 -26.764271  2.167044  -7.692026 -5.582357  ... -3.025406 -1.386471
# 3 -30.090614  1.326732  -9.913951 -5.376187  ... -2.718958 -1.582056
# 4 -30.606417  8.506790 -11.671857 -2.848767  ...  2.407784 -9.469318
#
#           13        14         15        16        17        18         19  \
# 0 -17.611557  5.692104 -14.337687 -5.510109 -5.364412 -2.164049  -9.902680
# 1 -14.230103  1.318771 -10.284133 -7.991556 -3.371053 -4.564389  -8.358080
# 2 -16.307165  5.676712 -13.477029 -6.213636 -5.351099 -2.271984  -9.357913
# 3 -18.145391  6.376534 -14.375193 -5.678218 -5.658622 -2.409917 -10.758000
# 4 -11.759858  4.560306 -17.916590 -3.649880 -7.469810 -2.707529 -12.072610
#
#    labels
# 0   happy
# 1   happy
# 2   happy
# 3   happy
# 4   happy
#
# [5 rows x 21 columns]

# %%
X = features.iloc[: ,: -1].values
Y = features['labels'].values

# %%
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state = 42, shuffle = True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((33489, 20), (33489, 6), (11163, 20), (11163, 6))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((33489, 20), (33489, 6), (11163, 20), (11163, 6))

# %%
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((33489, 20, 1), (33489, 6), (11163, 20, 1), (11163, 6))

# %%
model = Sequential([
    Conv1D(64, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu',input_shape = (x_train.shape[1], 1)),
    Conv1D(64, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu'),
    Dropout(0.25),
    MaxPooling1D(pool_size = 2, strides = 2, padding = 'same'),
    
    Conv1D(128, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu'),
    Conv1D(128, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu'),
    Conv1D(128, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu'),
    Dropout(0.25),
    MaxPooling1D(pool_size = 2, strides = 2, padding = 'same'),
    
    Conv1D(256, kernel_size = 3, strides = 1, padding = 'same', activation = 'relu'),
    
    Flatten(),
    Dense(units = 6, activation = 'softmax'),
    
])

model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)                    │ (None, 20, 64)              │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_3 (Conv1D)                    │ (None, 20, 64)              │          12,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 20, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 10, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_4 (Conv1D)                    │ (None, 10, 128)             │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_5 (Conv1D)                    │ (None, 10, 128)             │          49,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_6 (Conv1D)                    │ (None, 10, 128)             │          49,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 10, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_3 (MaxPooling1D)       │ (None, 5, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_7 (Conv1D)                    │ (None, 5, 256)              │          98,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │           7,686 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 242,118 (945.77 KB)
#  Trainable params: 242,118 (945.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=4, min_lr=0.0000001)
mdcp = ModelCheckpoint('best_speech_emotion_model_weights.keras', monitor='val_accuracy', save_best_only=True)
# early_stop = EarlyStopping(monitor='val_accuracy', mode='auto', patience=10, restore_best_weights=True)

history = model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[rlrp, mdcp])
# Out:
# Epoch 1/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 83s 59ms/step - accuracy: 0.3538 - loss: 1.5422 - val_accuracy: 0.4269 - val_loss: 1.4083 - learning_rate: 0.0010
# Epoch 2/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.4349 - loss: 1.3939 - val_accuracy: 0.4579 - val_loss: 1.3512 - learning_rate: 0.0010
# Epoch 3/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 0.4608 - loss: 1.3407 - val_accuracy: 0.4755 - val_loss: 1.3054 - learning_rate: 0.0010
# Epoch 4/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.4864 - loss: 1.2823 - val_accuracy: 0.5022 - val_loss: 1.2417 - learning_rate: 0.0010
# Epoch 5/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 0.5099 - loss: 1.2284 - val_accuracy: 0.5184 - val_loss: 1.2122 - learning_rate: 0.0010
# Epoch 6/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 18s 35ms/step - accuracy: 0.5377 - loss: 1.1684 - val_accuracy: 0.5522 - val_loss: 1.1360 - learning_rate: 0.0010
# Epoch 7/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.5701 - loss: 1.0933 - val_accuracy: 0.5795 - val_loss: 1.0861 - learning_rate: 0.0010
# Epoch 8/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - accuracy: 0.5998 - loss: 1.0217 - val_accuracy: 0.6001 - val_loss: 1.0418 - learning_rate: 0.0010
# Epoch 9/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.6246 - loss: 0.9681 - val_accuracy: 0.6216 - val_loss: 0.9849 - learning_rate: 0.0010
# Epoch 10/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.6553 - loss: 0.8915 - val_accuracy: 0.6464 - val_loss: 0.9377 - learning_rate: 0.0010
# Epoch 11/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.6737 - loss: 0.8388 - val_accuracy: 0.6655 - val_loss: 0.8983 - learning_rate: 0.0010
# Epoch 12/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 18s 35ms/step - accuracy: 0.6990 - loss: 0.7951 - val_accuracy: 0.6856 - val_loss: 0.8603 - learning_rate: 0.0010
# Epoch 13/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.7103 - loss: 0.7527 - val_accuracy: 0.6957 - val_loss: 0.8257 - learning_rate: 0.0010
# Epoch 14/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 0.7254 - loss: 0.7196 - val_accuracy: 0.7098 - val_loss: 0.7928 - learning_rate: 0.0010
# Epoch 15/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 0.7360 - loss: 0.6888 - val_accuracy: 0.7123 - val_loss: 0.7765 - learning_rate: 0.0010
# Epoch 16/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.7515 - loss: 0.6519 - val_accuracy: 0.7254 - val_loss: 0.7567 - learning_rate: 0.0010
# Epoch 17/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.7576 - loss: 0.6373 - val_accuracy: 0.7322 - val_loss: 0.7440 - learning_rate: 0.0010
# Epoch 18/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.7716 - loss: 0.6005 - val_accuracy: 0.7395 - val_loss: 0.7236 - learning_rate: 0.0010
# Epoch 19/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.7807 - loss: 0.5747 - val_accuracy: 0.7491 - val_loss: 0.6924 - learning_rate: 0.0010
# Epoch 20/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.7870 - loss: 0.5565 - val_accuracy: 0.7426 - val_loss: 0.7069 - learning_rate: 0.0010
# Epoch 21/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 0.7932 - loss: 0.5477 - val_accuracy: 0.7605 - val_loss: 0.6718 - learning_rate: 0.0010
# Epoch 22/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.7977 - loss: 0.5305 - val_accuracy: 0.7611 - val_loss: 0.6704 - learning_rate: 0.0010
# Epoch 23/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.8042 - loss: 0.5210 - val_accuracy: 0.7676 - val_loss: 0.6550 - learning_rate: 0.0010
# Epoch 24/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.8141 - loss: 0.5015 - val_accuracy: 0.7663 - val_loss: 0.6547 - learning_rate: 0.0010
# Epoch 25/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 35ms/step - accuracy: 0.8175 - loss: 0.4852 - val_accuracy: 0.7673 - val_loss: 0.6520 - learning_rate: 0.0010
# Epoch 26/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.8239 - loss: 0.4696 - val_accuracy: 0.7708 - val_loss: 0.6446 - learning_rate: 0.0010
# Epoch 27/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.8277 - loss: 0.4605 - val_accuracy: 0.7749 - val_loss: 0.6333 - learning_rate: 0.0010
# Epoch 28/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.8286 - loss: 0.4630 - val_accuracy: 0.7797 - val_loss: 0.6240 - learning_rate: 0.0010
# Epoch 29/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.8321 - loss: 0.4439 - val_accuracy: 0.7820 - val_loss: 0.6170 - learning_rate: 0.0010
# Epoch 30/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8417 - loss: 0.4288 - val_accuracy: 0.7782 - val_loss: 0.6267 - learning_rate: 0.0010
# Epoch 31/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.8422 - loss: 0.4220 - val_accuracy: 0.7802 - val_loss: 0.6304 - learning_rate: 0.0010
# Epoch 32/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.8435 - loss: 0.4249 - val_accuracy: 0.7877 - val_loss: 0.6055 - learning_rate: 0.0010
# Epoch 33/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8431 - loss: 0.4224 - val_accuracy: 0.7801 - val_loss: 0.6370 - learning_rate: 0.0010
# Epoch 34/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.8506 - loss: 0.4057 - val_accuracy: 0.7825 - val_loss: 0.6279 - learning_rate: 0.0010
# Epoch 35/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.8474 - loss: 0.4032 - val_accuracy: 0.7909 - val_loss: 0.6076 - learning_rate: 0.0010
# Epoch 36/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 42s 41ms/step - accuracy: 0.8494 - loss: 0.4036 - val_accuracy: 0.7886 - val_loss: 0.6048 - learning_rate: 0.0010
# Epoch 37/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.8538 - loss: 0.3959 - val_accuracy: 0.7860 - val_loss: 0.6188 - learning_rate: 0.0010
# Epoch 38/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 42s 41ms/step - accuracy: 0.8544 - loss: 0.3915 - val_accuracy: 0.7867 - val_loss: 0.6233 - learning_rate: 0.0010
# Epoch 39/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8585 - loss: 0.3801 - val_accuracy: 0.7954 - val_loss: 0.6003 - learning_rate: 0.0010
# Epoch 40/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.8643 - loss: 0.3705 - val_accuracy: 0.7924 - val_loss: 0.6096 - learning_rate: 0.0010
# Epoch 41/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8630 - loss: 0.3700 - val_accuracy: 0.7923 - val_loss: 0.6094 - learning_rate: 0.0010
# Epoch 42/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8627 - loss: 0.3747 - val_accuracy: 0.7937 - val_loss: 0.6013 - learning_rate: 0.0010
# Epoch 43/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 42s 42ms/step - accuracy: 0.8664 - loss: 0.3652 - val_accuracy: 0.7986 - val_loss: 0.5882 - learning_rate: 0.0010
# Epoch 44/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 0.8674 - loss: 0.3598 - val_accuracy: 0.7915 - val_loss: 0.6108 - learning_rate: 0.0010
# Epoch 45/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 0.8716 - loss: 0.3482 - val_accuracy: 0.7944 - val_loss: 0.6003 - learning_rate: 0.0010
# Epoch 46/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.8683 - loss: 0.3540 - val_accuracy: 0.7943 - val_loss: 0.6088 - learning_rate: 0.0010
# Epoch 47/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8720 - loss: 0.3438 - val_accuracy: 0.7886 - val_loss: 0.6341 - learning_rate: 0.0010
# Epoch 48/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8700 - loss: 0.3519 - val_accuracy: 0.7921 - val_loss: 0.6250 - learning_rate: 0.0010
# Epoch 49/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 42s 42ms/step - accuracy: 0.8719 - loss: 0.3513 - val_accuracy: 0.7934 - val_loss: 0.6247 - learning_rate: 0.0010
# Epoch 50/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.8716 - loss: 0.3445 - val_accuracy: 0.7965 - val_loss: 0.6167 - learning_rate: 0.0010
# Epoch 51/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.8818 - loss: 0.3227 - val_accuracy: 0.7954 - val_loss: 0.6098 - learning_rate: 0.0010
# Epoch 52/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 40s 41ms/step - accuracy: 0.8764 - loss: 0.3342 - val_accuracy: 0.7978 - val_loss: 0.6085 - learning_rate: 0.0010
# Epoch 53/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8799 - loss: 0.3268 - val_accuracy: 0.7976 - val_loss: 0.6048 - learning_rate: 0.0010
# Epoch 54/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 41s 42ms/step - accuracy: 0.8809 - loss: 0.3269 - val_accuracy: 0.8039 - val_loss: 0.5967 - learning_rate: 0.0010
# Epoch 55/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.8831 - loss: 0.3205 - val_accuracy: 0.7953 - val_loss: 0.6000 - learning_rate: 0.0010
# Epoch 56/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 0.8961 - loss: 0.2738 - val_accuracy: 0.8113 - val_loss: 0.5681 - learning_rate: 4.0000e-04
# Epoch 57/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.9167 - loss: 0.2294 - val_accuracy: 0.8157 - val_loss: 0.5835 - learning_rate: 4.0000e-04
# Epoch 58/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9194 - loss: 0.2250 - val_accuracy: 0.8129 - val_loss: 0.5925 - learning_rate: 4.0000e-04
# Epoch 59/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.9144 - loss: 0.2319 - val_accuracy: 0.8144 - val_loss: 0.5871 - learning_rate: 4.0000e-04
# Epoch 60/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9217 - loss: 0.2145 - val_accuracy: 0.8130 - val_loss: 0.5918 - learning_rate: 4.0000e-04
# Epoch 61/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.9254 - loss: 0.2089 - val_accuracy: 0.8162 - val_loss: 0.5930 - learning_rate: 4.0000e-04
# Epoch 62/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 41ms/step - accuracy: 0.9245 - loss: 0.2070 - val_accuracy: 0.8168 - val_loss: 0.5869 - learning_rate: 4.0000e-04
# Epoch 63/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.9283 - loss: 0.1974 - val_accuracy: 0.8176 - val_loss: 0.5928 - learning_rate: 4.0000e-04
# Epoch 64/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.9279 - loss: 0.1949 - val_accuracy: 0.8166 - val_loss: 0.5938 - learning_rate: 4.0000e-04
# Epoch 65/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.9254 - loss: 0.2036 - val_accuracy: 0.8173 - val_loss: 0.5958 - learning_rate: 4.0000e-04
# Epoch 66/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.9316 - loss: 0.1909 - val_accuracy: 0.8189 - val_loss: 0.6119 - learning_rate: 4.0000e-04
# Epoch 67/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 40s 41ms/step - accuracy: 0.9321 - loss: 0.1872 - val_accuracy: 0.8169 - val_loss: 0.6028 - learning_rate: 4.0000e-04
# Epoch 68/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 43ms/step - accuracy: 0.9306 - loss: 0.1919 - val_accuracy: 0.8192 - val_loss: 0.6040 - learning_rate: 4.0000e-04
# Epoch 69/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.9314 - loss: 0.1872 - val_accuracy: 0.8174 - val_loss: 0.6126 - learning_rate: 4.0000e-04
# Epoch 70/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9348 - loss: 0.1825 - val_accuracy: 0.8178 - val_loss: 0.6024 - learning_rate: 4.0000e-04
# Epoch 71/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9325 - loss: 0.1822 - val_accuracy: 0.8134 - val_loss: 0.6171 - learning_rate: 4.0000e-04
# Epoch 72/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.9334 - loss: 0.1862 - val_accuracy: 0.8156 - val_loss: 0.6250 - learning_rate: 4.0000e-04
# Epoch 73/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 42s 43ms/step - accuracy: 0.9306 - loss: 0.1929 - val_accuracy: 0.8172 - val_loss: 0.6118 - learning_rate: 4.0000e-04
# Epoch 74/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.9358 - loss: 0.1799 - val_accuracy: 0.8166 - val_loss: 0.6116 - learning_rate: 4.0000e-04
# Epoch 75/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 22s 42ms/step - accuracy: 0.9367 - loss: 0.1739 - val_accuracy: 0.8213 - val_loss: 0.5972 - learning_rate: 4.0000e-04
# Epoch 76/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.9373 - loss: 0.1709 - val_accuracy: 0.8155 - val_loss: 0.6209 - learning_rate: 4.0000e-04
# Epoch 77/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9370 - loss: 0.1742 - val_accuracy: 0.8163 - val_loss: 0.6149 - learning_rate: 4.0000e-04
# Epoch 78/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 45ms/step - accuracy: 0.9351 - loss: 0.1786 - val_accuracy: 0.8176 - val_loss: 0.6119 - learning_rate: 4.0000e-04
# Epoch 79/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9353 - loss: 0.1757 - val_accuracy: 0.8182 - val_loss: 0.6305 - learning_rate: 4.0000e-04
# Epoch 80/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9382 - loss: 0.1691 - val_accuracy: 0.8163 - val_loss: 0.6225 - learning_rate: 4.0000e-04
# Epoch 81/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9399 - loss: 0.1662 - val_accuracy: 0.8216 - val_loss: 0.6158 - learning_rate: 1.6000e-04
# Epoch 82/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.9457 - loss: 0.1492 - val_accuracy: 0.8222 - val_loss: 0.6224 - learning_rate: 1.6000e-04
# Epoch 83/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9484 - loss: 0.1456 - val_accuracy: 0.8211 - val_loss: 0.6246 - learning_rate: 1.6000e-04
# Epoch 84/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - accuracy: 0.9482 - loss: 0.1443 - val_accuracy: 0.8221 - val_loss: 0.6201 - learning_rate: 1.6000e-04
# Epoch 85/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9467 - loss: 0.1456 - val_accuracy: 0.8235 - val_loss: 0.6122 - learning_rate: 1.6000e-04
# Epoch 86/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 45ms/step - accuracy: 0.9518 - loss: 0.1373 - val_accuracy: 0.8238 - val_loss: 0.6227 - learning_rate: 1.6000e-04
# Epoch 87/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 23s 44ms/step - accuracy: 0.9520 - loss: 0.1365 - val_accuracy: 0.8221 - val_loss: 0.6265 - learning_rate: 1.6000e-04
# Epoch 88/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9523 - loss: 0.1326 - val_accuracy: 0.8238 - val_loss: 0.6237 - learning_rate: 1.6000e-04
# Epoch 89/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9565 - loss: 0.1278 - val_accuracy: 0.8226 - val_loss: 0.6208 - learning_rate: 1.6000e-04
# Epoch 90/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9536 - loss: 0.1322 - val_accuracy: 0.8234 - val_loss: 0.6266 - learning_rate: 1.6000e-04
# Epoch 91/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9538 - loss: 0.1313 - val_accuracy: 0.8236 - val_loss: 0.6226 - learning_rate: 1.6000e-04
# Epoch 92/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 42s 46ms/step - accuracy: 0.9548 - loss: 0.1246 - val_accuracy: 0.8249 - val_loss: 0.6225 - learning_rate: 6.4000e-05
# Epoch 93/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9581 - loss: 0.1167 - val_accuracy: 0.8240 - val_loss: 0.6267 - learning_rate: 6.4000e-05
# Epoch 94/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - accuracy: 0.9568 - loss: 0.1184 - val_accuracy: 0.8232 - val_loss: 0.6296 - learning_rate: 6.4000e-05
# Epoch 95/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - accuracy: 0.9605 - loss: 0.1112 - val_accuracy: 0.8238 - val_loss: 0.6318 - learning_rate: 6.4000e-05
# Epoch 96/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - accuracy: 0.9583 - loss: 0.1137 - val_accuracy: 0.8246 - val_loss: 0.6337 - learning_rate: 6.4000e-05
# Epoch 97/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9603 - loss: 0.1128 - val_accuracy: 0.8245 - val_loss: 0.6305 - learning_rate: 6.4000e-05
# Epoch 98/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9586 - loss: 0.1189 - val_accuracy: 0.8259 - val_loss: 0.6368 - learning_rate: 6.4000e-05
# Epoch 99/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - accuracy: 0.9593 - loss: 0.1151 - val_accuracy: 0.8242 - val_loss: 0.6355 - learning_rate: 6.4000e-05
# Epoch 100/100
# 524/524 ━━━━━━━━━━━━━━━━━━━━ 24s 45ms/step - accuracy: 0.9586 - loss: 0.1134 - val_accuracy: 0.8273 - val_loss: 0.6296 - learning_rate: 6.4000e-05

# %%
print("Testing Accuracy: " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8305 - loss: 0.6379
# Testing Accuracy:  82.72866010665894 %

# %%
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()

# %%
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0          neutral       neutral
# 1              sad           sad
# 2              sad         angry
# 3          disgust       disgust
# 4            happy         happy
# 5          neutral       neutral
# 6          disgust       disgust
# 7              sad           sad
# 8            happy         happy
# 9            angry         angry

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (12, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.show()

# %%
y_pred_labels = np.argmax(y_pred, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

accuracy = accuracy_score(y_test_labels, y_pred_labels)
precision = precision_score(y_test_labels, y_pred_labels, average='weighted')
recall = recall_score(y_test_labels, y_pred_labels, average='weighted')
f1 = f1_score(y_test_labels, y_pred_labels, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-score: {f1}")

print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
#               precision    recall  f1-score   support
#
#        angry       0.88      0.88      0.88      1896
#      disgust       0.80      0.80      0.80      1903
#         fear       0.81      0.79      0.80      1905
#        happy       0.82      0.82      0.82      1898
#      neutral       0.81      0.81      0.81      1642
#          sad       0.84      0.86      0.85      1919
#
#     accuracy                           0.83     11163
#    macro avg       0.83      0.83      0.83     11163
# weighted avg       0.83      0.83      0.83     11163

# %%
# Save model architecture to JSON
model_json = model.to_json()
with open("Speech_emotion_detection_model.json", "w") as json_file:
    json_file.write(model_json)

# Save model weights
model.save_weights("Speech_emotion_detection_model.weights.h5")

print("Model architecture and weights saved successfully!")
# Out:
# Model architecture and weights saved successfully!

# %%
import importlib.metadata

required_packages = [
    "pandas",
    "numpy",
    "librosa",
    "seaborn",
    "matplotlib",
    "scikit-learn",
    "ipython",
    "keras",          
    "tensorflow",     
]

with open("requirements.txt", "w") as f:
    for package in required_packages:
        try:
            version = importlib.metadata.version(package)
            f.write(f"{package}=={version}\n")
        except importlib.metadata.PackageNotFoundError:
            print(f"Warning: {package} is not installed.")
            f.write(f"{package}\n")  

print(" requirements.txt file with exact versions has been created.")
# Out:
#  requirements.txt file with exact versions has been created.
